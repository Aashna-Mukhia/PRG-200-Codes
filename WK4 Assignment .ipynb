# %%
inventory = {
    "rice": {"price": 120, "stock": 20},
    "milk": {"price": 90, "stock": 10},
    "bread": {"price": 60, "stock": 15},
    "eggs": {"price": 15, "stock": 30}
}

cart = {
    "rice": 2,
    "milk": 3,
    "eggs": 12
}

def process_order(inventory, cart):

    total = 0

    print("---- Bill ----")

    for item in cart:

        quantity = cart[item]

        if quantity <= inventory[item]["stock"]:

            cost = quantity * inventory[item]["price"]
            total += cost

            inventory[item]["stock"] -= quantity

            print(item, "x" + str(quantity), "= NPR", cost)

        else:
            print("Sorry, not enough stock for", item)

    print("Grand Total: NPR", total)
    
    print("----------------")

    print("\nUpdated stock:", end=" ")

    stock_list = []

    for item in inventory:
        stock_list.append(item + "=" + str(inventory[item]["stock"]))

    print(", ".join(stock_list))
    
process_order(inventory, cart)
# Out:
# ---- Bill ----
# rice x2 = NPR 240
# milk x3 = NPR 270
# eggs x12 = NPR 180
# Grand Total: NPR 690
# ----------------
#
# Updated stock: rice=18, milk=7, bread=15, eggs=18

# %%
sensors = [
    ("Chatara", 2.8),
    ("Tribeni Ghat", 5.4),
    ("Koshi Barrage", 4.1),
    ("Sunsari Bridge", 1.9),
    ("Saptakoshi Camp", 6.0)
]

def check_water_level(location, level_metres):

    if level_metres < 3:
        return "Safe"

    elif level_metres <= 5:
        return "Warning - Alert nearby villages"

    else:
        return "DANGER - Evacuate immediately!"

for location, level_metres in sensors:

    result = check_water_level(location, level_metres)

    print(location, "(", level_metres, "m ):", result)
# Out:
# Chatara ( 2.8 m ): Safe
# Tribeni Ghat ( 5.4 m ): DANGER - Evacuate immediately!
# Koshi Barrage ( 4.1 m ): Warning - Alert nearby villages
# Sunsari Bridge ( 1.9 m ): Safe
# Saptakoshi Camp ( 6.0 m ): DANGER - Evacuate immediately!

# %%
def convert_date(date_str, from_cal, to_cal):
    if from_cal == to_cal:
        return date_str
    
    year, month, day = date_str.split('-')
    year = int(year)
    
    if from_cal == "AD" and to_cal == "BS":
        year += 56
    elif from_cal == "BS" and to_cal == "AD":
        year -= 56
    
    return f"{year:04d}-{month}-{day}"

bs_months = ["Baisakh", "Jestha", "Ashadh", "Shrawan", "Bhadra", "Ashwin",
             "Kartik", "Mangsir", "Poush", "Magh", "Falgun", "Chaitra"]

customers = [
    {"name": "Ramesh Thapa", "date": "1985-06-24", "cal": "AD", "need": "BS", "style": "full"},
    {"name": "Sunita Karki", "date": "2055-09-10", "cal": "BS", "need": "AD", "style": "iso"},
    {"name": "Bikash Rai", "date": "1998-11-30", "cal": "AD", "need": "BS", "style": "nepali"},
    {"name": "Anjali Gurung", "date": "2040-01-05", "cal": "BS", "need": "AD", "style": "full"}
]

for c in customers:
    converted_date = convert_date(c["date"], c["cal"], c["need"])
    
    if c["style"] == "full" and c["need"] == "BS":
        y, m, d = converted_date.split('-')
        month_name = bs_months[int(m)-1]
        print(f"{c['name']} | Original: {c['date']} {c['cal']} | Converted: {int(d)}th {month_name}, {y} BS")
    else:
        print(f"{c['name']} | Original: {c['date']} {c['cal']} | Converted: {converted_date} {c['need']}")
# Out:
# Ramesh Thapa | Original: 1985-06-24 AD | Converted: 24th Ashwin, 2041 BS
# Sunita Karki | Original: 2055-09-10 BS | Converted: 1999-09-10 AD
# Bikash Rai | Original: 1998-11-30 AD | Converted: 2054-11-30 BS
# Anjali Gurung | Original: 2040-01-05 BS | Converted: 1984-01-05 AD

# %%
text = """
Nepal is a beautiful country. Nepal has Mount Everest.
Everest is the highest mountain in the world.
Many tourists visit Nepal every year to see Everest and other mountains.
Nepal is known for its mountains and natural beauty.
"""

def word_frequency(text):

    text = text.lower()

    text = text.replace(".", "")
    text = text.replace(",", "")

    words = text.split()

    counts = {}

    for word in words:

        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1

    sorted_words = sorted(
        counts.items(),
        key=lambda x: x[1],
        reverse=True
    )

    print("Top 3 Words:")

    for word, count in sorted_words[:3]:
        print(word, "-", count, "times")

word_frequency(text)
# Out:
# Top 3 Words:
# nepal - 4 times
# is - 3 times
# everest - 3 times

# %%
accounts = {
    "A001": {"name": "Ramesh Thapa", "balance":15000 , "pin":"1234"},
    "A002": {"name": "Sunita Karki", "balance":8500 ,"pin":"5678"},
    "A003": {"name": "Bikash Rai", "balance": 22000, "pin":"9012"}
}

def atm(account_id, pin, action, amount=0):

    if account_id not in accounts:
        print("Account not found")
        return

    if pin != accounts[account_id]["pin"]:
        print("Incorrect PIN")
        return

    if action == "balance":
        print(accounts[account_id]["name"])
        print("Balance: NPR", accounts[account_id]["balance"])
    elif action == "deposit":
        accounts[account_id]["balance"] += amount
        print("Deposit successful")
        print("New Balance:", accounts[account_id]["balance"])
    elif action == "withdraw":
        if amount <= accounts[account_id]["balance"]:
            accounts[account_id]["balance"] -= amount
            print("Withdrawal successful")
            print("New Balance:", accounts[account_id]["balance"])
        else:
            print("Insufficient funds")

# Test Calls
atm("A001", "1234", "balance")
atm("A002", "0000", "withdraw", 2000)  #wrong pin
atm("A002", "5678", "deposit", 3000)
atm("A003", "9012", "withdraw", 25000)  #insufficient funds
atm("A004", "1111", "balance") #account not found
# Out:
# Ramesh Thapa
# Balance: NPR 15000
# Incorrect PIN
# Deposit successful
# New Balance: 11500
# Insufficient funds
# Account not found
